# %%
import pandas as pd
import numpy as np
import datetime

# %%
vdf = pd.read_csv('fruitvegprices-2017_2022.csv')

# %%
vdf
# Out:
#          category           item            variety        date  price  unit
# 0           fruit         apples  bramleys_seedling  2022-03-11   2.05    kg
# 1           fruit         apples  coxs_orange_group  2022-03-11   1.22    kg
# 2           fruit         apples    egremont_russet  2022-03-11   1.14    kg
# 3           fruit         apples           braeburn  2022-03-11   1.05    kg
# 4           fruit         apples               gala  2022-03-11   1.03    kg
# ...           ...            ...                ...         ...    ...   ...
# 9642  cut_flowers    alstromeria             indoor  2017-11-03   0.27  stem
# 9643  cut_flowers  chrysanthemum       indoor_spray  2017-11-03   0.22  stem
# 9644  cut_flowers        lillies           oriental  2017-11-03   0.70  stem
# 9645  cut_flowers      narcissus             indoor  2017-11-03   0.06  stem
# 9646   pot_plants       cyclamen              13_cm  2017-11-03   0.75  unit
#
# [9647 rows x 6 columns]

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# ### Ejercicio uno: realice un analisis de valores nulos
#
# En caso de existir valores nulos elimine esos registros

# %%
Analizando si hay valores nulos en nuestro dataset.. No se encontraron valores nulos

# %%
   vdf.isna()
# Out:
#       category   item  variety   date  price   unit
# 0        False  False    False  False  False  False
# 1        False  False    False  False  False  False
# 2        False  False    False  False  False  False
# 3        False  False    False  False  False  False
# 4        False  False    False  False  False  False
# ...        ...    ...      ...    ...    ...    ...
# 9642     False  False    False  False  False  False
# 9643     False  False    False  False  False  False
# 9644     False  False    False  False  False  False
# 9645     False  False    False  False  False  False
# 9646     False  False    False  False  False  False
#
# [9647 rows x 6 columns]

# %%
Analizando cuantos datos nulos hay por columna, no se encontraron datos nulos en las columnas

# %%
vdf.isnull().sum()
# Out:
# category    0
# item        0
# variety     0
# date        0
# price       0
# unit        0
# dtype: int64

# %% [markdown]
# ### Ejercicio dos: Por categoria, cuantos distintos items hay y cuantos distintos variety hay?
#
# El resultado debe de tener el siguiente formato de presentacion:

# %%
pd.DataFrame({
    "category" : ['cut_flowers','fruit']
    , "item_count" : [9,10]
    , "variety_Count" : [10,21]
})
# Out:
#       category  item_count  variety_Count
# 0  cut_flowers           9             10
# 1        fruit          10             21

# %% [markdown]
# Como nota en un mismo dataframe mostramos todo lo solicitado, usted debe de mostrar todas las categorias

# %%
x=vdf["category"].value_counts().to_frame("item_count")

# %%
x
# Out:
#              item_count
# vegetable          7264
# fruit              1992
# cut_flowers         342
# pot_plants           49

# %%
y=vdf["variety"].value_counts().to_frame("variety_Count")

# %%
y
# Out:
#                    variety_Count
# red                          353
# all_varieties                279
# all                          263
# bramleys_seedling            218
# little_gem                   218
# ...                          ...
# indoor_spray                  13
# stocks                         7
# peony                          7
# sweet_williams                 6
# 9_cm                           5
#
# [77 rows x 1 columns]

# %%
z=vdf["category"].value_counts().keys().tolist()

# %%
z
# Out:
# ['vegetable', 'fruit', 'cut_flowers', 'pot_plants']

# %%
w=vdf["category"].value_counts().tolist()

# %%
w
# Out:
# [7264, 1992, 342, 49]

# %% [markdown]
# ### Ejercicio tres: Para la combinacion item, variety muestre el ultimo valor registrado por año.
#
# Ejemplo de como debe de mostrar su respuesta

# %%
pd.DataFrame({
    "item" : ['Manzana']
    , "variety" : ['Gala']
    , "year" : [2022]
    , "last_price" :  [3.2]
})
# Out:
#       item variety  year  last_price
# 0  Manzana    Gala  2022         3.2

# %%
vdf["year"]=pd.DatetimeIndex(vdf['date']).year

# %%
vdf
# Out:
#          category           item            variety        date  price  unit  \
# 0           fruit         apples  bramleys_seedling  2022-03-11   2.05    kg
# 1           fruit         apples  coxs_orange_group  2022-03-11   1.22    kg
# 2           fruit         apples    egremont_russet  2022-03-11   1.14    kg
# 3           fruit         apples           braeburn  2022-03-11   1.05    kg
# 4           fruit         apples               gala  2022-03-11   1.03    kg
# ...           ...            ...                ...         ...    ...   ...
# 9642  cut_flowers    alstromeria             indoor  2017-11-03   0.27  stem
# 9643  cut_flowers  chrysanthemum       indoor_spray  2017-11-03   0.22  stem
# 9644  cut_flowers        lillies           oriental  2017-11-03   0.70  stem
# 9645  cut_flowers      narcissus             indoor  2017-11-03   0.06  stem
# 9646   pot_plants       cyclamen              13_cm  2017-11-03   0.75  unit
#
#       year
# 0     2022
# 1     2022
# 2     2022
# 3     2022
# 4     2022
# ...    ...
# 9642  2017
# 9643  2017
# 9644  2017
# 9645  2017
# 9646  2017
#
# [9647 rows x 7 columns]

# %%
vdf[["item","variety","year","price"]]
# Out:
#                item            variety  year  price
# 0            apples  bramleys_seedling  2022   2.05
# 1            apples  coxs_orange_group  2022   1.22
# 2            apples    egremont_russet  2022   1.14
# 3            apples           braeburn  2022   1.05
# 4            apples               gala  2022   1.03
# ...             ...                ...   ...    ...
# 9642    alstromeria             indoor  2017   0.27
# 9643  chrysanthemum       indoor_spray  2017   0.22
# 9644        lillies           oriental  2017   0.70
# 9645      narcissus             indoor  2017   0.06
# 9646       cyclamen              13_cm  2017   0.75
#
# [9647 rows x 4 columns]

# %%
vdf[
   vdf.duplicated(
        subset=["item","year"],
        keep="last",
   )
]
# Out:
#        category      item             variety        date  price  unit  year
# 0         fruit    apples   bramleys_seedling  2022-03-11   2.05    kg  2022
# 1         fruit    apples   coxs_orange_group  2022-03-11   1.22    kg  2022
# 2         fruit    apples     egremont_russet  2022-03-11   1.14    kg  2022
# 3         fruit    apples            braeburn  2022-03-11   1.05    kg  2022
# 4         fruit    apples                gala  2022-03-11   1.03    kg  2022
# ...         ...       ...                 ...         ...    ...   ...   ...
# 9626  vegetable   lettuce                 cos  2017-11-03   0.53  head  2017
# 9627  vegetable   lettuce  crisp_iceberg_type  2017-11-03   0.38  head  2017
# 9631  vegetable     onion          bulb_brown  2017-11-03   0.34    kg  2017
# 9632  vegetable     onion            bulb_red  2017-11-03   0.49    kg  2017
# 9639  vegetable  tomatoes               round  2017-11-03   0.97    kg  2017
#
# [9403 rows x 7 columns]

# %%
vdf.rename(columns={"price": "last_price"},inplace=True)

# %%
vdf[["item","variety","year","last_price"]]
# Out:
#                item            variety  year  last_price
# 0            apples  bramleys_seedling  2022        2.05
# 1            apples  coxs_orange_group  2022        1.22
# 2            apples    egremont_russet  2022        1.14
# 3            apples           braeburn  2022        1.05
# 4            apples               gala  2022        1.03
# ...             ...                ...   ...         ...
# 9642    alstromeria             indoor  2017        0.27
# 9643  chrysanthemum       indoor_spray  2017        0.22
# 9644        lillies           oriental  2017        0.70
# 9645      narcissus             indoor  2017        0.06
# 9646       cyclamen              13_cm  2017        0.75
#
# [9647 rows x 4 columns]

# %% [markdown]
# ### Ejercicio cuatro: Segun el ejercicio tres, que tanto aumento o disminuyo el precio de cada item-variety
#
# Ejemplo de como se debe de mostrar su respuesta

# %%
pd.DataFrame({
    "item" : ['Manzana','Manzana','Manzana']
    , "variety" : ['Gala','Gala','Gala']
    , "year" : [2020,2021,2022]
    , "last_price" :  [2.7,2.5,3.2]
    , "delta" : [0, (2.5-2.7), (3.2-2.5)]
})
# Out:
#       item variety  year  last_price  delta
# 0  Manzana    Gala  2020         2.7    0.0
# 1  Manzana    Gala  2021         2.5   -0.2
# 2  Manzana    Gala  2022         3.2    0.7

# %% [markdown]
# Segun nuestro ejemplo dummy para 2021 estuvo 0.2 centavos mas barato y en 2022 estuvo 0.7 centavos caro

# %%
rango = vdf["last_price"].max() - vdf["last_price"].min()

# %%
rango
# Out:
# 17.580000000000002

# %%
vdf["last_price"].size
# Out:
# 9647

# %%
vdf["delta"]=0
for i in range (1,9647):
    temp=vdf.last_price[i]
    vdf.delta[i]=(vdf.last_price[i+1]-temp)
    i+1
# Out:
# C:\Users\50497\AppData\Local\Temp/ipykernel_7488/162936977.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vdf.delta[i]=(vdf.last_price[i+1]-temp)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 9647 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7488/162936977.py in <module>
#       2 for i in range (1,9647):
#       3     temp=vdf.last_price[i]
# ----> 4     vdf.delta[i]=(vdf.last_price[i+1]-temp)
#       5     i+1
#       6
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     385                     return self._range.index(new_key)
#     386                 except ValueError as err:
# --> 387                     raise KeyError(key) from err
#     388             raise KeyError(key)
#     389         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 9647

# %%
vdf[["item","variety","year","last_price","delta"]]
# Out:
#                item            variety  year  last_price  delta
# 0            apples  bramleys_seedling  2022        2.05      0
# 1            apples  coxs_orange_group  2022        1.22      0
# 2            apples    egremont_russet  2022        1.14      0
# 3            apples           braeburn  2022        1.05      0
# 4            apples               gala  2022        1.03      0
# ...             ...                ...   ...         ...    ...
# 9642    alstromeria             indoor  2017        0.27      0
# 9643  chrysanthemum       indoor_spray  2017        0.22      0
# 9644        lillies           oriental  2017        0.70      0
# 9645      narcissus             indoor  2017        0.06      0
# 9646       cyclamen              13_cm  2017        0.75      0
#
# [9647 rows x 5 columns]

# %% [markdown]
# ### Ejercicio cinco: Cual es precio promedio por item, variety
#
# Ejemplo de como se debe de mostrar su respuesta

# %%
pd.DataFrame({
    "item" : ['Manzana']
    , "variety" : ['Gala']
    , "year-month" : ['2021-01']   
    , "avg-price" : [0.5]
})
# Out:
#       item variety year-month  avg-price
# 0  Manzana    Gala    2021-01        0.5

# %%
vdf.groupby(["variety"]).mean()
# Out:
#                last_price         year     delta
# variety
# 13_cm            1.388636  2017.750000 -0.113636
# 9_cm             0.766000  2018.000000  0.000000
# all              1.382129  2019.532319  0.030418
# all_other        1.747000  2019.540000  5.800000
# all_varieties    0.860108  2019.483871  1.175627
# ...                   ...          ...       ...
# turnip           1.232332  2019.544041  0.000000
# victoria         2.175161  2019.451613 -0.225806
# vine             1.518955  2019.380597  0.529851
# white            0.482202  2019.522936  0.000000
# yelloworange     1.060580  2018.971014 -0.231884
#
# [77 rows x 3 columns]

# %% [markdown]
# ### Ejercicio seis: muestre por category,item,variety que tanto % ha aumentado su precio
#
# Ejemplo: si para las manzanas gala el primer precio que se registro fue 2.00 y el ultimo precio que se registro es 4.00 este aumento un 100%

# %%
pd.DataFrame({
    "category": ["fruta","fruta"]
    ,"item" : ['Manzana','Manzana']
    , "variety" : ['Gala','egremont_russet']
    , "percentage-change-between-first-and-last-price" : [200,150]       
})
# Out:
#   category     item          variety  \
# 0    fruta  Manzana             Gala
# 1    fruta  Manzana  egremont_russet
#
#    percentage-change-between-first-and-last-price
# 0                                             200
# 1                                             150

# %%
vdf.loc[: , "percentage-change-between-first-and-last-price"]=vdf["last_price"].mean()

# %%
vdf[["category","item","variety","delta"]]
# Out:
#                                                    category           item  \
# 0                                                     fruit         apples
# 1                                                     fruit         apples
# 2                                                     fruit         apples
# 3                                                     fruit         apples
# 4                                                     fruit         apples
# ...                                                     ...            ...
# 9643                                            cut_flowers  chrysanthemum
# 9644                                            cut_flowers        lillies
# 9645                                            cut_flowers      narcissus
# 9646                                             pot_plants       cyclamen
# percentage-change-between-first-and-last-price          NaN            NaN
#
#                                                           variety        date  \
# 0                                               bramleys_seedling  2022-03-11
# 1                                               coxs_orange_group  2022-03-11
# 2                                                 egremont_russet  2022-03-11
# 3                                                        braeburn  2022-03-11
# 4                                                            gala  2022-03-11
# ...                                                           ...         ...
# 9643                                                 indoor_spray  2017-11-03
# 9644                                                     oriental  2017-11-03
# 9645                                                       indoor  2017-11-03
# 9646                                                        13_cm  2017-11-03
# percentage-change-between-first-and-last-price                NaN         NaN
#
#                                                 last_price  unit         year  \
# 0                                                 2.050000    kg  2022.000000
# 1                                                 1.220000    kg  2022.000000
# 2                                                 1.140000    kg  2022.000000
# 3                                                 1.050000    kg  2022.000000
# 4                                                 1.030000    kg  2022.000000
# ...                                                    ...   ...          ...
# 9643                                              0.220000  stem  2017.000000
# 9644                                              0.700000  stem  2017.000000
# 9645                                              0.060000  stem  2017.000000
# 9646                                              0.750000  unit  2017.000000
# percentage-change-between-first-and-last-price    1.528333   NaN  2019.448326
#
#                                                    delta  \
# 0                                               0.000000
# 1                                               0.000000
# 2                                               0.000000
# 3                                               0.000000
# 4                                               0.000000
# ...                                                  ...
# 9643                                            0.000000
# 9644                                            0.000000
# 9645                                            0.000000
# 9646                                            0.000000
# percentage-change-between-first-and-last-price -0.018866
#
#                                                 percentage-change-between-first-and-last-price
# 0                                                                                     1.528333
# 1                                                                                     1.528333
# 2                                                                                     1.528333
# 3                                                                                     1.528333
# 4                                                                                     1.528333
# ...                                                                                        ...
# 9643                                                                                  1.528333
# 9644                                                                                  1.528333
# 9645                                                                                  1.528333
# 9646                                                                                  1.528333
# percentage-change-between-first-and-last-price                                        1.528333
#
# [9648 rows x 9 columns]

# %% [markdown]
# ### Ejercicio siete: Segun el ejercicio seis por category cual es el item,variety con mayor aumento de crecimiento
#
# Segun el ejemplo dummy que se utilizo en el ejercicio seis para la category fruta se mostraria la manzana gala unicamente
